# %% [markdown]
# This feature selection notebook does a filter followed by a wrapper for a binary dependent variable (binary classification). It's capable of doing the filter on more than one file. The variable files are called vars1.csv, vars2.csv ... Or you can make the input file name(s) anything you want.
#
# The filter runs separately on each vars file and keeps the top num_filter variables from each file. If there are more than one vars files we'll again select the top num_filter variables across all the vars.csv files.
#
# If balance = 0 the entire files are used. If balance != 0 then balance is the RATIO OF BADS TO GOODS retained for the rest of the feature selection. We keep all the rare class (bads) and downsample the goods. I think in general it's better to keep balance = 0.
#
# I've got an annoying warning message from the wrapper and I can't figure out how to get rid of it. If anybody figures this out please send a message to stevecoggeshall@gmail.com

# %%
import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import datetime as dt
import gc
from sklearn.ensemble import RandomForestClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from lightgbm import LGBMClassifier
# %matplotlib inline
start_time = dt.datetime.now()

# %%
print(pd.__version__)
# Out:
# 1.5.3

# %%
# set some parameters
num_files = 1
# I recommend set num_filter to be about 10 to 20% of the original # variables
num_filter = 300
# I recommend set num_wrapper to be about 50, then look for a saturation of the model performance as variables are added
# Then you can run it again with num_wrapper just a bit above this saturation point, not more than about twice this saturation number
num_wrapper = 50
balance = 0
detect_rate = .03
index_name = 'record'
y_name = 'fraud_label'
good_label = 0
bad_label = 1

# %% [markdown]
# ## Run a filter on all the files

# %%
# %%time
filter_score_df_list = []
for i in range(num_files):
#     file_name = "vars"+str(i+1)+'.csv'
    file_name = 'vars.csv'
    df = pd.read_csv(file_name)
    print("********** working on",file_name,"size is",df.shape)
    df = df.set_index(index_name) 
    df = df[df.index <= 833507] # remove the last two months as the out-of-time data (OOT)
    df = df[df.index >= 38511] # remove the first 2 weeks of records since their variables aren't well formed
    df['RANDOM'] = np.random.ranf(len(df)) # add a random number variable to make sure it doesn't come up as important
    goods = df[df[y_name] == good_label]
    bads = df[df[y_name] == bad_label]
    
    del df # don't need this file anymore
    num_goods = len(goods)
    num_bads = len(bads)
    num_vars = len(bads.columns)-2
    if(balance != 0):
        if(i == 0):
            num_goods_desired = int(min(num_goods,num_bads*balance))
            goods = goods.sample(n=num_goods_desired,random_state=1)
            goods_keep = list(goods.index)
            goods_keep.sort()
    
        if(i > 0):
            goods = goods.loc[goods_keep] 
            
    df_sampled = pd.concat([goods,bads])
    df_sampled.sort_index(inplace=True)
    filter_score = pd.DataFrame(np.zeros((num_vars+1,2)))
    filter_score.columns = ['variable','filter score']   
    j = 0
    for column in df_sampled:
        filter_score.loc[j,'variable'] = column
        filter_score.loc[j,'filter score'] = sps.ks_2samp(goods[column],bads[column])[0]
        j = j+1
        if j%100 == 0:
            print(j)

    filter_score.sort_values(by=['filter score'], ascending=False, inplace=True)
    vars_keep = list(filter_score['variable'][1:num_filter+1]) 
    print(file_name,filter_score.head(20))
    if(i == 0): # if first time through need to initialize some stuff
        Y = pd.DataFrame(df_sampled[y_name], index=df_sampled.index)
        df_top = df_sampled.filter(vars_keep, axis=1)
            
    if(i > 0): # if more than one variable file we use this loop
        data_new_top = df_sampled.filter(vars_keep, axis=1)
        df_top = pd.concat([df_top,data_new_top], axis=1)

    filter_score_df_list.append(filter_score)
    
    del goods # delete these before starting the next file, if any
    del bads
    gc.collect()
filter_score = pd.concat(filter_score_df_list)
# Out:
# ********** working on vars.csv size is (1000000, 2242)
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# vars.csv                                             variable  filter score
# 0                                        fraud_label      1.000000
# 2128                     max_count_by_fulladdress_30      0.359914
# 2108                         max_count_by_address_30      0.359215
# 2107                          max_count_by_address_7      0.343335
# 2127                      max_count_by_fulladdress_7      0.343052
# 10                                 address_day_since      0.334140
# 45                             fulladdress_day_since      0.333269
# 16                                  address_count_30      0.332648
# 51                              fulladdress_count_30      0.331969
# 2126                      max_count_by_fulladdress_3      0.329538
# 2106                          max_count_by_address_3      0.329445
# 15                                  address_count_14      0.322436
# 50                              fulladdress_count_14      0.321953
# 2105                          max_count_by_address_1      0.315332
# 2125                      max_count_by_fulladdress_1      0.315253
# 14                                   address_count_7      0.301735
# 49                               fulladdress_count_7      0.301666
# 514       address_unique_count_for_name_homephone_60      0.292438
# 175                            address_count_0_by_30      0.291922
# 528   address_unique_count_for_homephone_name_dob_60      0.291410
# CPU times: total: 18min 59s
# Wall time: 24min 37s

# %%
filter_score.sort_values(by=['filter score'], ascending=False, inplace=True)
filter_score.reset_index(drop=True,inplace=True)

# %%
filter_score.head(30)
# Out:
#                                              variable  filter score
# 0                                         fraud_label      1.000000
# 1                         max_count_by_fulladdress_30      0.359914
# 2                             max_count_by_address_30      0.359215
# 3                              max_count_by_address_7      0.343335
# 4                          max_count_by_fulladdress_7      0.343052
# 5                                   address_day_since      0.334140
# 6                               fulladdress_day_since      0.333269
# 7                                    address_count_30      0.332648
# 8                                fulladdress_count_30      0.331969
# 9                          max_count_by_fulladdress_3      0.329538
# 10                             max_count_by_address_3      0.329445
# 11                                   address_count_14      0.322436
# 12                               fulladdress_count_14      0.321953
# 13                             max_count_by_address_1      0.315332
# 14                         max_count_by_fulladdress_1      0.315253
# 15                                    address_count_7      0.301735
# 16                                fulladdress_count_7      0.301666
# 17         address_unique_count_for_name_homephone_60      0.292438
# 18                              address_count_0_by_30      0.291922
# 19     address_unique_count_for_homephone_name_dob_60      0.291410
# 20                          fulladdress_count_0_by_30      0.290722
# 21      fulladdress_unique_count_for_ssn_homephone_60      0.289991
# 22               address_unique_count_for_ssn_zip5_60      0.289724
# 23               address_unique_count_for_ssn_name_60      0.289679
# 24     fulladdress_unique_count_for_name_homephone_60      0.289535
# 25          address_unique_count_for_ssn_homephone_60      0.289166
# 26  fulladdress_unique_count_for_homephone_name_do...      0.288483
# 27      fulladdress_unique_count_for_dob_homephone_60      0.288443
# 28          address_unique_count_for_ssn_firstname_60      0.288127
# 29           address_unique_count_for_ssn_name_dob_60      0.287645

# %%
filter_score.tail(10)
# Out:
#                                                variable  filter score
# 2232   ssn_fulladdress_unique_count_for_ssn_firstname_1      0.000004
# 2233      ssn_zip5_unique_count_for_name_fulladdress_30      0.000003
# 2234           ssn_dob_unique_count_for_ssn_firstname_0      0.000003
# 2235         homephone_name_dob_unique_count_for_zip5_0      0.000003
# 2236           ssn_zip5_unique_count_for_ssn_lastname_1      0.000003
# 2237               ssn_zip5_unique_count_for_address_14      0.000002
# 2238               ssn_lastname_unique_count_for_name_0      0.000001
# 2239          name_fulladdress_unique_count_for_zip5_30      0.000001
# 2240  ssn_fulladdress_unique_count_for_ssn_firstname_60      0.000001
# 2241             fulladdress_unique_count_for_address_0      0.000000

# %%
filter_score.shape
# Out:
# (2242, 2)

# %%
filter_score.head(80).to_csv('filter_top.csv')
vars_keep = list(filter_score['variable'][num_files:num_filter+3])
print(i,' vars_keep:',vars_keep)
# Out:
# 0  vars_keep: ['max_count_by_fulladdress_30', 'max_count_by_address_30', 'max_count_by_address_7', 'max_count_by_fulladdress_7', 'address_day_since', 'fulladdress_day_since', 'address_count_30', 'fulladdress_count_30', 'max_count_by_fulladdress_3', 'max_count_by_address_3', 'address_count_14', 'fulladdress_count_14', 'max_count_by_address_1', 'max_count_by_fulladdress_1', 'address_count_7', 'fulladdress_count_7', 'address_unique_count_for_name_homephone_60', 'address_count_0_by_30', 'address_unique_count_for_homephone_name_dob_60', 'fulladdress_count_0_by_30', 'fulladdress_unique_count_for_ssn_homephone_60', 'address_unique_count_for_ssn_zip5_60', 'address_unique_count_for_ssn_name_60', 'fulladdress_unique_count_for_name_homephone_60', 'address_unique_count_for_ssn_homephone_60', 'fulladdress_unique_count_for_homephone_name_dob_60', 'fulladdress_unique_count_for_dob_homephone_60', 'address_unique_count_for_ssn_firstname_60', 'address_unique_count_for_ssn_name_dob_60', 'address_unique_count_for_dob_homephone_60', 'address_unique_count_for_ssn_lastname_60', 'address_unique_count_for_name_60', 'fulladdress_unique_count_for_ssn_name_60', 'fulladdress_unique_count_for_ssn_lastname_60', 'fulladdress_unique_count_for_ssn_60', 'fulladdress_unique_count_for_ssn_firstname_60', 'address_unique_count_for_ssn_60', 'address_unique_count_for_name_dob_60', 'fulladdress_unique_count_for_ssn_name_dob_60', 'fulladdress_unique_count_for_ssn_dob_60', 'fulladdress_unique_count_for_name_60', 'address_unique_count_for_name_homephone_30', 'fulladdress_unique_count_for_ssn_homephone_30', 'address_unique_count_for_homephone_name_dob_30', 'address_unique_count_for_ssn_dob_60', 'fulladdress_unique_count_for_name_homephone_30', 'fulladdress_unique_count_for_homephone_name_dob_30', 'address_unique_count_for_ssn_homephone_30', 'fulladdress_unique_count_for_name_dob_60', 'fulladdress_unique_count_for_dob_homephone_30', 'fulladdress_unique_count_for_dob_60', 'address_unique_count_for_ssn_name_30', 'address_unique_count_for_ssn_zip5_30', 'address_unique_count_for_dob_60', 'address_unique_count_for_ssn_name_dob_30', 'fulladdress_unique_count_for_ssn_name_30', 'fulladdress_unique_count_for_ssn_firstname_30', 'fulladdress_unique_count_for_ssn_lastname_30', 'fulladdress_unique_count_for_ssn_30', 'address_count_0_by_14', 'address_unique_count_for_dob_homephone_30', 'address_unique_count_for_ssn_lastname_30', 'address_unique_count_for_ssn_firstname_30', 'fulladdress_unique_count_for_ssn_name_dob_30', 'fulladdress_unique_count_for_ssn_dob_30', 'fulladdress_count_0_by_14', 'address_unique_count_for_ssn_30', 'address_unique_count_for_name_30', 'address_unique_count_for_name_dob_30', 'address_unique_count_for_ssn_dob_30', 'fulladdress_unique_count_for_name_30', 'fulladdress_unique_count_for_name_dob_30', 'fulladdress_unique_count_for_dob_30', 'fulladdress_count_3', 'address_count_3', 'address_unique_count_for_name_homephone_14', 'address_unique_count_for_homephone_name_dob_14', 'fulladdress_unique_count_for_ssn_homephone_14', 'fulladdress_unique_count_for_name_homephone_14', 'address_unique_count_for_dob_30', 'address_unique_count_for_ssn_homephone_14', 'fulladdress_unique_count_for_homephone_name_dob_14', 'address_unique_count_for_ssn_name_14', 'address_unique_count_for_ssn_zip5_14', 'fulladdress_unique_count_for_dob_homephone_14', 'address_unique_count_for_ssn_lastname_14', 'address_unique_count_for_ssn_name_dob_14', 'fulladdress_unique_count_for_ssn_name_14', 'address_unique_count_for_dob_homephone_14', 'fulladdress_unique_count_for_ssn_firstname_14', 'fulladdress_unique_count_for_ssn_lastname_14', 'fulladdress_unique_count_for_ssn_14', 'address_unique_count_for_ssn_firstname_14', 'fulladdress_unique_count_for_ssn_name_dob_14', 'fulladdress_unique_count_for_ssn_dob_14', 'address_unique_count_for_ssn_14', 'address_unique_count_for_name_14', 'address_unique_count_for_ssn_dob_14', 'address_unique_count_for_name_dob_14', 'fulladdress_unique_count_for_name_14', 'fulladdres ...

# %%
vars_keep_df = pd.DataFrame({'col':vars_keep})
vars_keep_df.to_csv('vars_keep_filter.csv',index=False)
df_keep = df_top.filter(vars_keep, axis=1)
df_keep.head()
# Out:
#          max_count_by_fulladdress_30  max_count_by_address_30  \
# record
# 38511.0                         14.0                     14.0
# 38512.0                          1.0                      1.0
# 38513.0                          1.0                      1.0
# 38514.0                          1.0                      1.0
# 38515.0                          1.0                      1.0
#
#          max_count_by_address_7  max_count_by_fulladdress_7  \
# record
# 38511.0                    10.0                        10.0
# 38512.0                     1.0                         1.0
# 38513.0                     1.0                         1.0
# 38514.0                     1.0                         1.0
# 38515.0                     1.0                         1.0
#
#          address_day_since  fulladdress_day_since  address_count_30  \
# record
# 38511.0                0.0                    0.0              12.0
# 38512.0              365.0                  365.0               1.0
# 38513.0              365.0                  365.0               1.0
# 38514.0              365.0                  365.0               1.0
# 38515.0              365.0                  365.0               1.0
#
#          fulladdress_count_30  max_count_by_fulladdress_3  \
# record
# 38511.0                  12.0                         6.0
# 38512.0                   1.0                         1.0
# 38513.0                   1.0                         1.0
# 38514.0                   1.0                         1.0
# 38515.0                   1.0                         1.0
#
#          max_count_by_address_3  ...  name_dob_count_0_by_30  \
# record                           ...
# 38511.0                     6.0  ...                    30.0
# 38512.0                     1.0  ...                    30.0
# 38513.0                     1.0  ...                    30.0
# 38514.0                     1.0  ...                    30.0
# 38515.0                     1.0  ...                    30.0
#
#          zip5_unique_count_for_ssn_homephone_7  \
# record
# 38511.0                                    8.0
# 38512.0                                    3.0
# 38513.0                                    6.0
# 38514.0                                    2.0
# 38515.0                                    1.0
#
#          zip5_unique_count_for_ssn_firstname_7  zip5_unique_count_for_ssn_7  \
# record
# 38511.0                                    8.0                          8.0
# 38512.0                                    3.0                          3.0
# 38513.0                                    6.0                          6.0
# 38514.0                                    2.0                          2.0
# 38515.0                                    1.0                          1.0
#
#          zip5_unique_count_for_ssn_lastname_7  \
# record
# 38511.0                                   8.0
# 38512.0                                   3.0
# 38513.0                                   6.0
# 38514.0                                   2.0
# 38515.0                                   1.0
#
#          zip5_unique_count_for_ssn_name_7  \
# record
# 38511.0                               8.0
# 38512.0                               3.0
# 38513.0                               6.0
# 38514.0                               2.0
# 38515.0                               1.0
#
#          zip5_unique_count_for_name_homephone_7  \
# record
# 38511.0                                     8.0
# 38512.0                                     3.0
# 38513.0                                     6.0
# 38514.0                                     2.0
# 38515.0                                     1.0
#
#          zip5_unique_count_for_ssn_address_7  \
# record
# 38511.0                                  8.0
# 38512.0                                  3.0
# 38513.0                                  6.0
# 38514.0                                  2.0
# 38515.0                                  1.0
#
#          zip5_unique_count_for_dob_homephone_7  \
# record
# 38511.0                                    8.0
# 38512.0                                    3.0
# 38513.0                                    6.0
# 38514.0                                    2.0
# 38515.0                                    1.0
#
#          zip5_unique_count_for_homephone_name_dob_7
# record
# 38511.0                                         8.0
# 38512.0                                         3.0
# 38513.0                                         6.0
# 38514.0                                         2.0
# 38515.0                                         1.0
#
# [5 rows x 300 columns]

# %%
df_keep.shape
# Out:
# (794997, 300)

# %%
Y.head()
# Out:
#          fraud_label
# record
# 38511.0          1.0
# 38512.0          0.0
# 38513.0          0.0
# 38514.0          0.0
# 38515.0          0.0

# %%
Y = Y.values
Y_save = Y.copy()

# %%
# Y = np.array(Y)
X = df_keep
print(Y)
# Out:
# [[1.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
print('time to here:', dt.datetime.now() - start_time)
# Out:
# time to here: 0:24:38.422250

# %%
print(X.shape,Y.shape)
# Out:
# (794997, 300) (794997, 1)

# %%
print(type(X),type(Y))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'numpy.ndarray'>

# %%
# I'd like to define a scoring for the wrapper that's KS, but I haven't gotten around to this yet.
# def KSscore(classifier, x,y)
#     goods =

# %%
def fdr(classifier, x, y, cutoff=detect_rate):
# Calculates FDR score for the given classifier on dataset x and y with cutoff value
# get the probability list from the given classifier
    return fdr_prob(y, classifier.predict_proba(x), cutoff)
def fdr_prob(y, y_prob, cutoff=detect_rate):
    if len(y_prob.shape) != 1:    # sometimes the proba list can contain many columns, one for each category
        y_prob = y_prob[:, -1:]   # only the last one (fraud_label==1) is used here.
    num_fraud = len(y[y == 1])    # count the total nunber of frauds   
# sort the proba list from high to low while retain the true (not predicted) fraud label
    sorted_prob = np.asarray(sorted(zip(y_prob, y), key=lambda x: x[0], reverse=True))
    cutoff_bin = sorted_prob[0:int(len(y) * cutoff), 1:]  # 3% cutoff
# return the FDR score (#fraud_in_cutoff / #total_fraud)
    return len(cutoff_bin[cutoff_bin == 1]) / num_fraud

# %% [markdown]
# ## Run a wrapper on the remaining top variables

# %%
# %%time
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning) 
# If you're doing forward selection it's enough to stop at num_wrapper variables. 
# If you're doing backward selection you need to go through all the variables to get a sorted list of num_wrapper variables.

# I can't figure out how to get rid of this annoying warning! I don't know what I'm doing wrong...

nfeatures = len(X.columns)
# clf = RandomForestClassifier(n_estimators=5) # simple, fast nonlinear model for the wrapper
clf = LGBMClassifier(n_estimators=20,num_leaves=3) # simple, fast nonlinear model for the wrapper
sfs = SFS(clf,k_features=num_wrapper,forward=True,verbose=0,scoring=fdr,cv=3,n_jobs=-1) # use for forward selection
# sfs = SFS(clf,k_features=1,forward=False,verbose=0,scoring=fdr,cv=3,n_jobs=-1) # use for backward selection
sfs.fit(X,Y)
# Out:
# CPU times: total: 2min 34s
# Wall time: 8h 35min 7s
# SequentialFeatureSelector(cv=3,
#                           estimator=LGBMClassifier(n_estimators=20,
#                                                    num_leaves=3),
#                           k_features=(50, 50), n_jobs=-1,
#                           scoring=<function fdr at 0x000001EC90205040>)

# %%
print('time to here:', dt.datetime.now() - start_time)
# Out:
# time to here: 8:59:45.880808

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
fig1 = plot_sfs(sfs.get_metric_dict(),kind='std_dev', figsize=(15, 6))
plt.xticks(np.arange(0, len(X.columns), step=5))
plt.yticks(np.arange(0,1,step=.1))
plt.ylim([0., 1])
plt.xlim(0,num_wrapper)
plt.title('Stepwise Selection')
plt.grid()
plt.savefig('performance_nvars.png')
plt.show()

# %%
vars_FS = pd.DataFrame.from_dict(sfs.get_metric_dict()).T

# %%
ordered_vars_FS = vars_FS.copy()
for i in range(len(ordered_vars_FS)):
    ordered_vars_FS.loc[i+1,'add variables in this order'] = int(i+1)
    if i+1 == 1:
        ordered_vars_FS.loc[i+1,'variable name'] = (list(ordered_vars_FS.loc[i+1,'feature_names'])[0])
    else:
        ordered_vars_FS.loc[i+1,'variable name'] = (list(set(ordered_vars_FS.loc[i+1,'feature_names']) - set(ordered_vars_FS.loc[i,'feature_names'])))
# You might also need this following line. It converts a list to a string
        ordered_vars_FS.loc[i+1,'variable name'] = ordered_vars_FS.loc[i+1,'variable name'][0]

# %%
ordered_vars_FS
# Out:
#                                           feature_idx  \
# 1                                                (1,)
# 2                                            (1, 205)
# 3                                       (1, 205, 225)
# 4                                  (1, 205, 225, 244)
# 5                               (0, 1, 205, 225, 244)
# 6                          (0, 1, 205, 225, 227, 244)
# 7                     (0, 1, 199, 205, 225, 227, 244)
# 8                (0, 1, 192, 199, 205, 225, 227, 244)
# 9            (0, 1, 19, 192, 199, 205, 225, 227, 244)
# 10      (0, 1, 19, 192, 199, 205, 217, 225, 227, 244)
# 11  (0, 1, 19, 192, 199, 205, 217, 225, 227, 244, ...
# 12  (0, 1, 5, 19, 192, 199, 205, 217, 225, 227, 24...
# 13  (0, 1, 5, 19, 21, 192, 199, 205, 217, 225, 227...
# 14  (0, 1, 5, 19, 21, 159, 192, 199, 205, 217, 225...
# 15  (0, 1, 5, 6, 19, 21, 159, 192, 199, 205, 217, ...
# 16  (0, 1, 2, 5, 6, 19, 21, 159, 192, 199, 205, 21...
# 17  (0, 1, 2, 4, 5, 6, 19, 21, 159, 192, 199, 205,...
# 18  (0, 1, 2, 4, 5, 6, 8, 19, 21, 159, 192, 199, 2...
# 19  (0, 1, 2, 4, 5, 6, 8, 9, 19, 21, 159, 192, 199...
# 20  (0, 1, 2, 4, 5, 6, 8, 9, 10, 19, 21, 159, 192,...
# 21  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 19, 21, 159, ...
# 22  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 19, 21, 1...
# 23  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 19, 2...
# 24  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 25  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 26  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 27  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 28  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 29  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 30  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 31  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 32  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 33  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 34  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 35  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 36  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 37  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 38  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 39  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 40  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 41  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 42  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 43  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 44  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 45  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 46  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 47  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 48  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 49  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
# 50  (0, 1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 1...
#
#                                             cv_scores avg_score  \
# 1   [0.35361713241055104, 0.41028989292243406, 0.3...  0.379647
# 2   [0.5270305562810134, 0.5620266388090885, 0.559...  0.549491
# 3   [0.5701227474536432, 0.5949334029772787, 0.586...  0.583877
# 4   [0.5769130321232698, 0.6087751371115173, 0.606...  0.597545
# 5   [0.5931052494123792, 0.6228780360407417, 0.617...    0.6113
# 6   [0.5938887437973361, 0.6228780360407417, 0.620...  0.612344
# 7   [0.5983285453120919, 0.6202663880908853, 0.619...   0.61278
# 8   [0.6001566988769914, 0.6286236615304257, 0.621...  0.616784
# 9   [0.5993732044920345, 0.6307129798903108, 0.622...  0.617568
# 10  [0.5993732044920345, 0.6314964742752677, 0.623...  0.618003
# 11  [0.5985897101070775, 0.6328022982501958, 0.625...  0.618874
# 12  [0.5996343692870201, 0.6338469574301384, 0.625...   0.61957
# 13  [0.5998955340820058, 0.6338469574301384, 0.625...  0.619657
# 14  [0.5998955340820058, 0.6343692870201096, 0.625...  0.619918
# 15  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 16  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 17  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 18  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 19  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 20  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 21  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 22  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 23  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 24  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 25  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 26  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 27  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 28  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 29  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 30  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 31  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 32  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 33  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 34  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 35  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 36  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 37  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 38  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 39  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 40  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 41  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 42  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 43  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 44  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 45  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 46  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 47  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 48  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 49  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
# 50  [0.5998955340820058, 0.634891616610081, 0.6254...  0.620092
#
#                                         feature_names  ci_bound   std_dev  \
# 1                          (max_count_by_address_30,)   0.05258  0.023365
# 2   (max_count_by_address_30, max_count_by_ssn_dob_7)   0.03582  0.015917
# 3   (max_count_by_address_30, max_count_by_ssn_dob...  0.023194  0.010307
# 4   (max_count_by_address_30, max_count_by_ssn_dob...  0.032873  0.014608
# 5   (max_count_by_fulladdress_30, max_count_by_add...  0.029308  0.013024
# 6   (max_count_by_fulladdress_30, max_count_by_add...  0.029465  0.013094
# 7   (max_count_by_fulladdress_30, max_count_by_add...     0.023  0.010221
# 8   (max_count_by_fulladdress_30, max_count_by_add...   0.02724  0.012105
# 9   (max_count_by_fulladdress_30, max_count_by_add...  0.029892  0.013283
# 10  (max_count_by_fulladdress_30, max_count_by_add...  0.030622  0.013608
# 11  (max_count_by_fulladdress_30, max_count_by_add...  0.033018  0.014672
# 12  (max_count_by_fulladdress_30, max_count_by_add...  0.032695  0.014529
# 13  (max_count_by_fulladdress_30, max_count_by_add...  0.032426   0.01441
# 14  (max_count_by_fulladdress_30, max_count_by_add...  0.032888  0.014615
# 15  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 16  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 17  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 18  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 19  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 20  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 21  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 22  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 23  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 24  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 25  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 26  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 27  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 28  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 29  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 30  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 31  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 32  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 33  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 34  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 35  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 36  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 37  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 38  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 39  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 40  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 41  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 42  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 43  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 44  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 45  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 46  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 47  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 48  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 49  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
# 50  (max_count_by_fulladdress_30, max_count_by_add...  0.033278  0.014788
#
#      std_err  add variables in this order  \
# 1   0.016522                          1.0
# 2   0.011255                          2.0
# 3   0.007288                          3.0
# 4   0.010329                          4.0
# 5   0.009209                          5.0
# 6   0.009259                          6.0
# 7   0.007227                          7.0
# 8   0.008559                          8.0
# 9   0.009393                          9.0
# 10  0.009622                         10.0
# 11  0.010375                         11.0
# 12  0.010274                         12.0
# 13  0.010189                         13.0
# 14  0.010334                         14.0
# 15  0.010457                         15.0
# 16  0.010457                         16.0
# 17  0.010457                         17.0
# 18  0.010457                         18.0
# 19  0.010457                         19.0
# 20  0.010457                         20.0
# 21  0.010457                         21.0
# 22  0.010457                         22.0
# 23  0.010457                         23.0
# 24  0.010457                         24.0
# 25  0.010457                         25.0
# 26  0.010457                         26.0
# 27  0.010457                         27.0
# 28  0.010457                         28.0
# 29  0.010457                         29.0
# 30  0.010457                         30.0
# 31  0.010457                         31.0
# 32  0.010457                         32.0
# 33  0.010457                         33.0
# 34  0.010457                         34.0
# 35  0.010457                         35.0
# 36  0.010457                         36.0
# 37  0.010457                         37.0
# 38  0.010457                         38.0
# 39  0.010457                         39.0
# 40  0.010457                         40.0
# 41  0.010457                         41.0
# 42  0.010457                         42.0
# 43  0.010457                         43.0
# 44  0.010457                         44.0
# 45  0.010457                         45.0
# 46  0.010457                         46.0
# 47  0.010457                         47.0
# 48  0.010457                         48.0
# 49  0.010457                         49.0
# 50  0.010457                         50.0
#
#                                         variable name
# 1                             max_count_by_address_30
# 2                              max_count_by_ssn_dob_7
# 3                            max_count_by_homephone_3
# 4                                        zip5_count_1
# 5                         max_count_by_fulladdress_30
# 6                                max_count_by_name_30
# 7                            max_count_by_homephone_7
# 8                             max_count_by_ssn_dob_30
# 9                           fulladdress_count_0_by_30
# 10                            ssn_firstname_day_since
# 11                          max_count_by_homephone_30
# 12                              fulladdress_day_since
# 13               address_unique_count_for_ssn_zip5_60
# 14              max_count_by_fulladdress_homephone_30
# 15                                   address_count_30
# 16                             max_count_by_address_7
# 17                                  address_day_since
# 18                         max_count_by_fulladdress_3
# 19                             max_count_by_address_3
# 20                                   address_count_14
# 21                               fulladdress_count_14
# 22                             max_count_by_address_1
# 23                         max_count_by_fulladdress_1
# 24                                    address_count_7
# 25                                fulladdress_count_7
# 26         address_unique_count_for_name_homephone_60
# 27                              address_count_0_by_30
# 28     address_unique_count_for_homephone_name_dob_60
# 29      fulladdress_unique_count_for_ssn_homephone_60
# 30               address_unique_count_for_ssn_name_60
# 31     fulladdress_unique_count_for_name_homephone_60
# 32          address_unique_count_for_ssn_homephone_60
# 33  fulladdress_unique_count_for_homephone_name_do...
# 34      fulladdress_unique_count_for_dob_homephone_60
# 35          address_unique_count_for_ssn_firstname_60
# 36           address_unique_count_for_ssn_name_dob_60
# 37          address_unique_count_for_dob_homephone_60
# 38           address_unique_count_for_ssn_lastname_60
# 39                   address_unique_count_for_name_60
# 40           fulladdress_unique_count_for_ssn_name_60
# 41       fulladdress_unique_count_for_ssn_lastname_60
# 42                fulladdress_unique_count_for_ssn_60
# 43      fulladdress_unique_count_for_ssn_firstname_60
# 44                    address_unique_count_for_ssn_60
# 45               address_unique_count_for_name_dob_60
# 46       fulladdress_unique_count_for_ssn_name_dob_60
# 47            fulladdress_unique_count_for_ssn_dob_60
# 48               fulladdress_unique_count_for_name_60
# 49         address_unique_count_for_name_homephone_30
# 50      fulladdress_unique_count_for_ssn_homephone_30

# %%
ordered_vars_FS.to_csv('Wrapper_selection_info.csv', index=False)

# %%
vars_keep = ordered_vars_FS['variable name']
vars_keep_list = ordered_vars_FS['variable name'].tolist()
vars_keep.to_csv('final_vars_list.csv',index=False)
vars_keep
# Out:
# 1                               max_count_by_address_30
# 2                                max_count_by_ssn_dob_7
# 3                              max_count_by_homephone_3
# 4                                          zip5_count_1
# 5                           max_count_by_fulladdress_30
# 6                                  max_count_by_name_30
# 7                              max_count_by_homephone_7
# 8                               max_count_by_ssn_dob_30
# 9                             fulladdress_count_0_by_30
# 10                              ssn_firstname_day_since
# 11                            max_count_by_homephone_30
# 12                                fulladdress_day_since
# 13                 address_unique_count_for_ssn_zip5_60
# 14                max_count_by_fulladdress_homephone_30
# 15                                     address_count_30
# 16                               max_count_by_address_7
# 17                                    address_day_since
# 18                           max_count_by_fulladdress_3
# 19                               max_count_by_address_3
# 20                                     address_count_14
# 21                                 fulladdress_count_14
# 22                               max_count_by_address_1
# 23                           max_count_by_fulladdress_1
# 24                                      address_count_7
# 25                                  fulladdress_count_7
# 26           address_unique_count_for_name_homephone_60
# 27                                address_count_0_by_30
# 28       address_unique_count_for_homephone_name_dob_60
# 29        fulladdress_unique_count_for_ssn_homephone_60
# 30                 address_unique_count_for_ssn_name_60
# 31       fulladdress_unique_count_for_name_homephone_60
# 32            address_unique_count_for_ssn_homephone_60
# 33    fulladdress_unique_count_for_homephone_name_do...
# 34        fulladdress_unique_count_for_dob_homephone_60
# 35            address_unique_count_for_ssn_firstname_60
# 36             address_unique_count_for_ssn_name_dob_60
# 37            address_unique_count_for_dob_homephone_60
# 38             address_unique_count_for_ssn_lastname_60
# 39                     address_unique_count_for_name_60
# 40             fulladdress_unique_count_for_ssn_name_60
# 41         fulladdress_unique_count_for_ssn_lastname_60
# 42                  fulladdress_unique_count_for_ssn_60
# 43        fulladdress_unique_count_for_ssn_firstname_60
# 44                      address_unique_count_for_ssn_60
# 45                 address_unique_count_for_name_dob_60
# 46         fulladdress_unique_count_for_ssn_name_dob_60
# 47              fulladdress_unique_count_for_ssn_dob_60
# 48                 fulladdress_unique_count_for_name_60
# 49           address_unique_count_for_name_homephone_30
# 50        fulladdress_unique_count_for_ssn_homephone_30
# Name: variable name, dtype: object

# %%
filter_score.set_index('variable',drop=True,inplace=True)
filter_score = filter_score.iloc[1:,:]
filter_score
# Out:
#                                                    filter score
# variable
# max_count_by_fulladdress_30                            0.359914
# max_count_by_address_30                                0.359215
# max_count_by_address_7                                 0.343335
# max_count_by_fulladdress_7                             0.343052
# address_day_since                                      0.334140
# ...                                                         ...
# ssn_zip5_unique_count_for_address_14                   0.000002
# ssn_lastname_unique_count_for_name_0                   0.000001
# name_fulladdress_unique_count_for_zip5_30              0.000001
# ssn_fulladdress_unique_count_for_ssn_firstname_60      0.000001
# fulladdress_unique_count_for_address_0                 0.000000
#
# [2241 rows x 1 columns]

# %%
vars_keep_sorted = pd.DataFrame(vars_keep_list)
vars_keep_sorted.columns=['variable']
vars_keep_sorted.set_index('variable',drop=True,inplace=True)
vars_keep_sorted.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [max_count_by_address_30, max_count_by_ssn_dob_7, max_count_by_homephone_3, zip5_count_1, max_count_by_fulladdress_30]

# %%
vars_keep_sorted = pd.concat([vars_keep_sorted,filter_score],axis=1,join='inner')

# %%
vars_keep_sorted.reset_index(inplace=True)
vars_keep_sorted.reset_index(inplace=True)
vars_keep_sorted['index'] = vars_keep_sorted['index'] + 1
vars_keep_sorted.rename(columns={'index':'wrapper order'},inplace=True)
vars_keep_sorted.to_csv('vars_keep_sorted.csv',index=False)
vars_keep_sorted
# Out:
#     wrapper order                                           variable  \
# 0               1                            max_count_by_address_30
# 1               2                             max_count_by_ssn_dob_7
# 2               3                           max_count_by_homephone_3
# 3               4                                       zip5_count_1
# 4               5                        max_count_by_fulladdress_30
# 5               6                               max_count_by_name_30
# 6               7                           max_count_by_homephone_7
# 7               8                            max_count_by_ssn_dob_30
# 8               9                          fulladdress_count_0_by_30
# 9              10                            ssn_firstname_day_since
# 10             11                          max_count_by_homephone_30
# 11             12                              fulladdress_day_since
# 12             13               address_unique_count_for_ssn_zip5_60
# 13             14              max_count_by_fulladdress_homephone_30
# 14             15                                   address_count_30
# 15             16                             max_count_by_address_7
# 16             17                                  address_day_since
# 17             18                         max_count_by_fulladdress_3
# 18             19                             max_count_by_address_3
# 19             20                                   address_count_14
# 20             21                               fulladdress_count_14
# 21             22                             max_count_by_address_1
# 22             23                         max_count_by_fulladdress_1
# 23             24                                    address_count_7
# 24             25                                fulladdress_count_7
# 25             26         address_unique_count_for_name_homephone_60
# 26             27                              address_count_0_by_30
# 27             28     address_unique_count_for_homephone_name_dob_60
# 28             29      fulladdress_unique_count_for_ssn_homephone_60
# 29             30               address_unique_count_for_ssn_name_60
# 30             31     fulladdress_unique_count_for_name_homephone_60
# 31             32          address_unique_count_for_ssn_homephone_60
# 32             33  fulladdress_unique_count_for_homephone_name_do...
# 33             34      fulladdress_unique_count_for_dob_homephone_60
# 34             35          address_unique_count_for_ssn_firstname_60
# 35             36           address_unique_count_for_ssn_name_dob_60
# 36             37          address_unique_count_for_dob_homephone_60
# 37             38           address_unique_count_for_ssn_lastname_60
# 38             39                   address_unique_count_for_name_60
# 39             40           fulladdress_unique_count_for_ssn_name_60
# 40             41       fulladdress_unique_count_for_ssn_lastname_60
# 41             42                fulladdress_unique_count_for_ssn_60
# 42             43      fulladdress_unique_count_for_ssn_firstname_60
# 43             44                    address_unique_count_for_ssn_60
# 44             45               address_unique_count_for_name_dob_60
# 45             46       fulladdress_unique_count_for_ssn_name_dob_60
# 46             47            fulladdress_unique_count_for_ssn_dob_60
# 47             48               fulladdress_unique_count_for_name_60
# 48             49         address_unique_count_for_name_homephone_30
# 49             50      fulladdress_unique_count_for_ssn_homephone_30
#
#     filter score
# 0       0.359215
# 1       0.228401
# 2       0.224757
# 3       0.221239
# 4       0.359914
# 5       0.222191
# 6       0.232235
# 7       0.240836
# 8       0.290722
# 9       0.226428
# 10      0.215931
# 11      0.333269
# 12      0.289724
# 13      0.249724
# 14      0.332648
# 15      0.343335
# 16      0.334140
# 17      0.329538
# 18      0.329445
# 19      0.322436
# 20      0.321953
# 21      0.315332
# 22      0.315253
# 23      0.301735
# 24      0.301666
# 25      0.292438
# 26      0.291922
# 27      0.291410
# 28      0.289991
# 29      0.289679
# 30      0.289535
# 31      0.289166
# 32      0.288483
# 33      0.288443
# 34      0.288127
# 35      0.287645
# 36      0.287556
# 37      0.287444
# 38      0.287411
# 39      0.286799
# 40      0.286776
# 41      0.286764
# 42      0.286763
# 43      0.285913
# 44      0.285912
# 45      0.284731
# 46      0.284689
# 47      0.284534
# 48      0.284516
# 49      0.284087

# %%
vars_keep_list.append(index_name)
vars_keep_list.append(y_name)
vars_keep_list
# Out:
# ['max_count_by_address_30',
#  'max_count_by_ssn_dob_7',
#  'max_count_by_homephone_3',
#  'zip5_count_1',
#  'max_count_by_fulladdress_30',
#  'max_count_by_name_30',
#  'max_count_by_homephone_7',
#  'max_count_by_ssn_dob_30',
#  'fulladdress_count_0_by_30',
#  'ssn_firstname_day_since',
#  'max_count_by_homephone_30',
#  'fulladdress_day_since',
#  'address_unique_count_for_ssn_zip5_60',
#  'max_count_by_fulladdress_homephone_30',
#  'address_count_30',
#  'max_count_by_address_7',
#  'address_day_since',
#  'max_count_by_fulladdress_3',
#  'max_count_by_address_3',
#  'address_count_14',
#  'fulladdress_count_14',
#  'max_count_by_address_1',
#  'max_count_by_fulladdress_1',
#  'address_count_7',
#  'fulladdress_count_7',
#  'address_unique_count_for_name_homephone_60',
#  'address_count_0_by_30',
#  'address_unique_count_for_homephone_name_dob_60',
#  'fulladdress_unique_count_for_ssn_homephone_60',
#  'address_unique_count_for_ssn_name_60',
#  'fulladdress_unique_count_for_name_homephone_60',
#  'address_unique_count_for_ssn_homephone_60',
#  'fulladdress_unique_count_for_homephone_name_dob_60',
#  'fulladdress_unique_count_for_dob_homephone_60',
#  'address_unique_count_for_ssn_firstname_60',
#  'address_unique_count_for_ssn_name_dob_60',
#  'address_unique_count_for_dob_homephone_60',
#  'address_unique_count_for_ssn_lastname_60',
#  'address_unique_count_for_name_60',
#  'fulladdress_unique_count_for_ssn_name_60',
#  'fulladdress_unique_count_for_ssn_lastname_60',
#  'fulladdress_unique_count_for_ssn_60',
#  'fulladdress_unique_count_for_ssn_firstname_60',
#  'address_unique_count_for_ssn_60',
#  'address_unique_count_for_name_dob_60',
#  'fulladdress_unique_count_for_ssn_name_dob_60',
#  'fulladdress_unique_count_for_ssn_dob_60',
#  'fulladdress_unique_count_for_name_60',
#  'address_unique_count_for_name_homephone_30',
#  'fulladdress_unique_count_for_ssn_homephone_30',
#  'record',
#  'fraud_label']

# %%
filter_score
# Out:
#                                                    filter score
# variable
# max_count_by_fulladdress_30                            0.359914
# max_count_by_address_30                                0.359215
# max_count_by_address_7                                 0.343335
# max_count_by_fulladdress_7                             0.343052
# address_day_since                                      0.334140
# ...                                                         ...
# ssn_zip5_unique_count_for_address_14                   0.000002
# ssn_lastname_unique_count_for_name_0                   0.000001
# name_fulladdress_unique_count_for_zip5_30              0.000001
# ssn_fulladdress_unique_count_for_ssn_firstname_60      0.000001
# fulladdress_unique_count_for_address_0                 0.000000
#
# [2241 rows x 1 columns]

# %%
# %%time
df = pd.read_csv(file_name)
df.shape
# Out:
# CPU times: total: 9min 5s
# Wall time: 11min
# (1000000, 2242)

# %%
df_keep = df.filter(vars_keep_list, axis=1)
# df_keep = df[df.index.isin(vars_keep_list)]
print(df_keep.shape)
# Out:
# (1000000, 52)

# %%
df_keep.to_csv('vars_final.csv',index=False)

# %%
print("duration: ", dt.datetime.now() - start_time)
# Out:
# duration:  9:11:14.089852
